# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# %%
cols = ["fLength", "fWidth", "fSize", "fConc", "fConc1", "fAsym", "fM3Long", "fM3Trans", "fAlpha", "fDist", "class"]
df = pd.read_csv('magic04.data', names=cols)
df.head()
# Out:
#     fLength    fWidth   fSize   fConc  fConc1     fAsym  fM3Long  fM3Trans  \
# 0   28.7967   16.0021  2.6449  0.3918  0.1982   27.7004  22.0110   -8.2027
# 1   31.6036   11.7235  2.5185  0.5303  0.3773   26.2722  23.8238   -9.9574
# 2  162.0520  136.0310  4.0612  0.0374  0.0187  116.7410 -64.8580  -45.2160
# 3   23.8172    9.5728  2.3385  0.6147  0.3922   27.2107  -6.4633   -7.1513
# 4   75.1362   30.9205  3.1611  0.3168  0.1832   -5.5277  28.5525   21.8393
#
#     fAlpha     fDist class
# 0  40.0920   81.8828     g
# 1   6.3609  205.2610     g
# 2  76.9600  256.7880     g
# 3  10.4490  116.7370     g
# 4   4.6480  356.4620     g

# %%
df['class'] =  (df['class'] == 'g').astype(int)

# %%
df['class'].unique()
# Out:
# array([1, 0])

# %% [markdown]
# # Machine Learning

# %% [markdown]
# AI & ML & DS have an overlap

# %% [markdown]
# ## Types of machine Learning

# %% [markdown]
# 1. Supervised Learning
# 2. Unsupervised Learning
# 3. Reinforcement Learning

# %% [markdown]
# ### 1. Supervised learning

# %% [markdown]
# ![image.png](attachment:bf2ee733-61dc-4fa0-8d39-1df645c7018a.png)

# %% [markdown]
# $$ Feature Factor = Inputs$$

# %% [markdown]
# For features we have :
# - Qualitative features ; which has nominal data and categorical \
# For nominal, we use **One-Hot encoding**, were we use zeros and ones\
# Categorical have an inherent odering in them.

# %% [markdown]
# ![image.png](attachment:efc3d3bb-e596-4296-b7d9-5c60437bd583.png)

# %% [markdown]
# some applications of machine learning is: \
# - classification, under this we can have either **Binary Classification** or **Multiclass Classification**.
# - We can also have regression, example is the price of a cow in 5 years time.

# %% [markdown]
# So How does the machine learn

# %% [markdown]
# ![image.png](attachment:85aef219-741d-4aca-b502-c16d400bc14a.png)

# %% [markdown]
# ![image.png](attachment:3c9cad33-b215-4806-b9f7-94dde7b94c55.png)

# %% [markdown]
# ![image.png](attachment:6639b5e5-4145-4bd9-9456-269954254ab5.png)

# %% [markdown]
# ![image.png](attachment:4219c15c-286f-4df5-a436-6c9513e6b046.png)

# %% [markdown]
# ![image.png](attachment:8b0a2e04-1413-4168-a154-2807316c0377.png)

# %% [markdown]
# ![image.png](attachment:840b7e6b-f2c1-4cee-ba25-3b06a9e1331c.png)

# %% [markdown]
# ![image.png](attachment:a1e81a21-c10b-4ed0-9703-74f30810d047.png)

# %% [markdown]
# ![image.png](attachment:0ce64cde-046b-4db8-b66e-034de6970f83.png)

# %% [markdown]
# ![image.png](attachment:27d70468-2700-4213-8eb2-53af1afda8c3.png)

# %% [markdown]
# ![image.png](attachment:9d837138-0c4a-4eb5-9a6b-b27bf6464e2a.png)

# %% [markdown]
# ![image.png](attachment:2e7a83fa-dac9-4e4b-bbdb-a8d5a7acb52c.png)

# %% [markdown]
# ![image.png](attachment:0d4bfbc4-1a46-439a-8105-eb18c4eae616.png)

# %% [markdown]
#  ![image.png](attachment:4ce4d562-86f5-425e-925c-685dc77648de.png)

# %% [markdown]
# ![image.png](attachment:fc7c8687-a866-41d8-8b28-47a4e01e9fe7.png)

# %% [markdown]
# ![image.png](attachment:877c7854-1db4-4e75-843b-e37b131aab7b.png)

# %% [markdown]
# ![image.png](attachment:a15fb4af-52c1-4f83-a592-e78ecfa4c1f7.png)

# %% [markdown]
# ![image.png](attachment:0f93b198-1492-4724-b7e4-987b27d5be9f.png)

# %%
 for label in cols[:-1]:
     plt.hist(df[df['class'] == 1][label], color='blue', label='gamma',alpha=0.7, density=True)
     plt.hist(df[df['class'] == 0][label], color='red', label='hadron', alpha = 0.7, density=True)
     plt.title(label)
     plt.ylabel('Probability')
     plt.xlabel(label)
     plt.legend()
     plt.show()

# %% [markdown]
# ## Train, Validation, Test Dataset

# %%
train, valid, test = np.split(df.sample(frac=1),[int(0.6*len(df)), int(0.8*len(df))])
# Out:
# /home/toxicity/jupyter_env/lib/python3.12/site-packages/numpy/_core/fromnumeric.py:57: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)

# %%
def scale_dataset(dataframe):
    x = dataframe[dataframe.cols[:-1]].values
    y = dataframe[dataframe.cols[-1]].values

    scaler = StandardScaler()
    X = scaler.fit_transform(X)

    data = np.hstack((X, np.reshape(y, (-1,1))))
    return data, X, y

# %%
train
# Out:
#         fLength   fWidth   fSize   fConc  fConc1    fAsym  fM3Long  fM3Trans  \
# 693     56.6968  23.5737  2.9309  0.2145  0.1284  64.9744  29.6956  -10.3543
# 7625    34.6876  12.4005  2.5472  0.3461  0.1745  26.3022 -18.9013    8.8459
# 3603    77.0826  25.4232  3.4002  0.2006  0.1041 -53.2658  69.2391  -20.8604
# 6597    57.0377  18.2816  3.3557  0.2217  0.1126  44.0953  40.1071   -8.7296
# 13267   34.9849  17.9934  2.8319  0.3623  0.2202  28.9533  34.1395   -9.3712
# ...         ...      ...     ...     ...     ...      ...      ...       ...
# 14066   30.9410  16.5982  2.4955  0.4335  0.2343   2.9095  26.7865    4.0661
# 14326  110.8670  40.7858  3.0616  0.2542  0.1297  88.0994  91.5093   32.7225
# 15413   16.2518  10.4497  2.4513  0.6060  0.3333  -0.1087  -8.2122    8.7514
# 5162    91.7756  29.9170  3.0179  0.2294  0.1224  86.9593  74.6589   26.8484
# 10860   29.4658  19.6390  2.9934  0.3503  0.1873  -4.3524  17.6604   -2.6286
#
#         fAlpha     fDist  class
# ...

# %%
print(len(train['class'] == 1
